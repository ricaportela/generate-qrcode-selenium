# %%
from __future__ import print_function
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from query_emails import ListMessagesMatchingQuery

# %%
SCOPES = 'https://www.googleapis.com/auth/gmail.readonly'

# %%
"""Shows basic usage of the Gmail API.
Lists the user's Gmail labels.
"""
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
store = file.Storage('token.json')
creds = store.get()
if not creds or creds.invalid:
    flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
    creds = tools.run_flow(flow, store)
service = build('gmail', 'v1', http=creds.authorize(Http()))

# %%
service.users().labels().list(userId='me').execute()
# Out:
# {'labels': [{'id': 'Label_7',
#    'name': '[Imap]/Enviados',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_51', 'name': 'RDZ', 'type': 'user'},
#   {'id': 'Label_61',
#    'name': '[Gmail]/Lixeira/Bruno Avila - Viver de Curso',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'CATEGORY_FORUMS',
#    'name': 'CATEGORY_FORUMS',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'Label_69', 'name': '[Gmail]/Dicas_RicardoPortela', 'type': 'user'},
#   {'id': 'Label_2',
#    'name': 'Templates',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_54',
#    'name': '[Gmail]/Microfocus',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_72',
#    'name': 'Rafael Henrique',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_55', 'name': '[Imap]/Sent', 'type': 'user'},
#   {'id': 'Label_67', 'name': '[Gmail]/FreeCamp', 'type': 'user'},
#   {'id': 'Label_66', 'name': '[Gmail]/Empregos Vagas Catho', 'type': 'user'},
#   {'id': 'Label_74',
#    'name': 'Python Pro',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_68', 'name': '[Gmail]/Python-Brasil', 'type': 'user'},
#   {'id': 'Label_71',
#    'name': 'Henrique Bastos',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'CATEGORY_PERSONAL', 'name': 'CATEGORY_PERSONAL', 'type': 'system'},
#   {'id': 'CATEGORY_SOCIAL',
#    'name': 'CATEGORY_SOCIAL',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'Label_57',
#    'name': '[Imap]/Drafts',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelHide',
#    'type': 'user'},
#   {'id': 'Label_44',
#    'name': '[Imap]/Trash',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'Label_58', 'name': '[Gmail]/Rebelk', 'type': 'user'},
#   {'id': 'Label_73',
#    'name': 'Openstack',
#    'messageListVisibility': 'show',
#    'labelListVisibility': 'labelShow',
#    'type': 'user'},
#   {'id': 'IMPORTANT',
#    'name': 'IMPORTANT',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'Label_60', 'name': '[Gmail]/Grupo Python', 'type': 'user'},
#   {'id': 'Label_63', 'name': '[Gmail]/Mazzatech', 'type': 'user'},
#   {'id': 'CATEGORY_UPDATES',
#    'name': 'CATEGORY_UPDATES',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'CHAT',
#    'name': 'CHAT',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'SENT',
#    'name': 'SENT',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'INBOX',
#    'name': 'INBOX',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'TRASH',
#    'name': 'TRASH',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'CATEGORY_PROMOTIONS',
#    'name': 'CATEGORY_PROMOTIONS',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'DRAFT',
#    'name': 'DRAFT',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'SPAM',
#    'name': 'SPAM',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'STARRED',
#    'name': 'STARRED',
#    'messageListVisibility': 'hide',
#    'labelListVisibility': 'labelShow',
#    'type': 'system'},
#   {'id': 'UNREAD', 'name': 'UNREAD', 'type': 'system'},
#   {'id': 'Label_75', 'name': 'Unroll.me', 'type': 'user'}]}

# %%
query='from: evan carmichael unstoppable '
user_id='me'

# %%
def ListMessagesMatchingQuery():
    try:
        response = service.users().messages().list(userId=user_id,
                                       q=query).execute()
        messages = []
        if 'messages' in response:
            messages.extend(response['messages'])

        while 'nextPageToken' in response:
            page_token = response['nextPageToken']
            response = service.users().messages().list(userId=user_id, q=query,
                                 pageToken=page_token).execute()
            messages.extend(response['messages'])

        return messages
    except errors.HttpError as error:
        print ('An error occurred: {}'.format(error))

# %%
msg = ListMessagesMatchingQuery()[0]

# %%
m_id = msg['id']

# %%
message = service.users().messages().get(userId=user_id, id=m_id).execute() # fetch the message using API

# %%
payld = message['payload'] # get payload of the message 
headr = payld['headers'] # get header of the payload

# %%
payld
# Out:
# {'partId': '',
#  'mimeType': 'multipart/alternative',
#  'filename': '',
#  'headers': [{'name': 'Delivered-To', 'value': 'ricaportela@gmail.com'},
#   {'name': 'Received',
#    'value': 'by 2002:aed:250b:0:0:0:0:0 with SMTP id v11csp3433476qtc;        Sat, 24 Nov 2018 02:08:02 -0800 (PST)'},
#   {'name': 'X-Google-Smtp-Source',
#    'value': 'AJdET5fHOGO+WaJcbw7/59dU+331j6Ud5la1n3st++R3exuWXfE5j1An6J3dUimORBvpCTiC58v5'},
#   {'name': 'X-Received',
#    'value': 'by 2002:ac8:690e:: with SMTP id e14mr17618936qtr.204.1543054082710;        Sat, 24 Nov 2018 02:08:02 -0800 (PST)'},
#   {'name': 'ARC-Seal',
#    'value': 'i=1; a=rsa-sha256; t=1543054082; cv=none;        d=google.com; s=arc-20160816;        b=0qOO1d/9bLmRqhCiFk7OlKI+8dYOx1E9NPw68e692Xfv17gFZtfR37c9xMWtwUJxAq         kUnSE47sXriKn0yTTB7OXEzP72IbfeUq9SUYgWIpC/kx4QWrAv1jRPEthX4YyjWXQS2s         gEH79DBc3AGu85Plp49le1o/qr+RnZxyYAstLHGAiU0mhHb3xBCZhHEafXQiXmLVRFbk         1PDl3DX569anILzcs+gIxnfjO+ns0HyytYdKAWNtDrxd/vUnDfeHXVjbQ0KPBHX/OzFJ         YFIfkGzarVa7QQty83hblkINTSA8OJmR6rI9ioY4tDB7hAwc0k1AEhMs9TFZbQWCPpti         Nz6w=='},
#   {'name': 'ARC-Message-Signature',
#    'value': 'i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=sender:from:reply-to:subject:list-unsubscribe:to:feedback-id         :message-id:x_id:mime-version:date:dkim-signature;        bh=h/+OILQfulxBO95yBsmhjZMdP9WQkLITEAun+btnFVE=;        b=jjBJytt4PlGMiKQAT//w2LsEeQWbfDFfmeCX0qR0KnPeNNMXCX4zS+N7tIiVXUY1BL         fl8kawjWt2AhlzYABiCBM42ddjtEwexZWpd7WmsxJMUBkcGfrWrPcMBBKEyAtTVOwbmn         tsy7J1R999cmb2Db4B4LbUBB1FF/Ny08thgawDZUrIslSBC6/a037neTAGoO6xJxc+Fq         bY9ynX3Bhrp7zddzolpiLCbB0d3/tTs2+k+gqu3+yXNzaVFNlEBj2W9rBH85cFSSyGsd         E/KwGWC/lPqep81xgTbIs7Wq9WvUTaH4xq7dbTCizf1Ssju1QzP90gFdCAs3Z7EOaLkm         cs7w=='},
#   {'name': 'ARC-Authentication-Results',
#    'value': 'i=1; mx.google.com;       dkim=pass header.i=@aweber.com header.s=20180823-2048-2e9cf629 header.b=q5leY5zA;       spf=pass (google.com: domain of razmhoxsbltszbwstgxmhlrmtmymjkycjcws@smtp-coi-g07-020.aweber.com designates 204.194.223.20 as permitted sender) smtp.mailfrom=rAzMHOxsbLTszBwsTGxMHLRmtMyMjKycjCws@smtp-coi-g07-020.aweber.com;       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=aweber.com'},
#   {'name': 'Return-Path',
#    'value': '<rAzMHOxsbLTszBwsTGxMHLRmtMyMjKycjCws@smtp-coi-g07-020.aweber.com>'},
#   {'name': 'Received',
#    'value': 'from smtp-coi-g07-020.aweber.com (smtp-coi-g07-020.aweber.com. [204.194.223.20])        by mx.google.com with ESMTPS id i10si3002815qke.104.2018.11.24.02.08.02        for <ricaportela@gmail.com>        (version=TLS1_2 cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Sat, 24 Nov 2018 02:08:02 -0800 (PST)'},
#   {'name': 'Received-SPF',
#    'value': 'pass (google.com: domain of razmhoxsbltszbwstgxmhlrmtmymjkycjcws@smtp-coi-g07-020.aweber.com designates 204.194.223.20 as permitted sender) client-ip=204.194.223.20;'},
#   {'name': 'Authentication-Results',
#    'value': 'mx.google.com;       dkim=pass header.i=@aweber.com header.s=20180823-2048-2e9cf629 header.b=q5leY5zA;       spf=pass (google.com: domain of razmhoxsbltszbwstgxmhlrmtmymjkycjcws@smtp-coi-g07-020.aweber.com designates 204.194.223.20 as permitted sender) smtp.mailfrom=rAzMHOxsbLTszBwsTGxMHLRmtMyMjKycjCws@smtp-coi-g07-020.aweber.com;       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=aweber.com'},
#   {'name': 'DKIM-Signature',
#    'value': 'v=1; a=rsa-sha256; c=relaxed/relaxed; d=aweber.com; s=20180823-2048-2e9cf629; t=1543054175; bh=h/+OILQfulxBO95yBsmhjZMdP9WQkLITEAun+btnFVE=; h=Date:Content-Type:MIME-Version:To:List-Unsubscribe:Subject:From:\t Sender; b=q5leY5zAQF+TUsR55wCR1c404x0KcNIKiqLL9ZM9dP5tIM6w1Sc9Ptp8EvoFa+LUJ\t X7S6OsZZ7/gJ0SPKEdZalnifuSa2AYzjopPx36fG+TF0Fm0qR8p/hKuifRriwKR+Qw\t tM5uSSguSsrLkyQpbu/scMujnKWscJlxOZix8YgRC8C2H0AQnHcn1UrS1ec+oE1EvO\t qsBiN+5w3WVuFNl3FQqADbOSjOHRWf+YD7/Si+DbUM8mi8ciyyztDE84YcisdPCdmE\t 1DdX8iUx6hfjZMzJrrSIaRM23DN92B2+hGW6BJhvPI0GUrTfUDde/FfNA0066vl+rn\t 3MYfvDqmLGd+Q=='},
#   {'name': 'Date', 'value': 'Sat, 24 Nov 2018 05:09:35 -0500'},
#   {'name': 'Content-Type',
#    'value': 'multipart/alternative; boundary="===============7515129286322499693=="'},
#   {'name': 'MIME-Version', 'value': '1.0'},
#   {'name': 'X-Loop', 'value': 'awlist5038766@aweber.com'},
#   {'name': 'X_Id', 'value': '5038766:127:ricaportela@gmail.com'},
#   {'name': 'Received',
#    'value': '(qmail 32387 invoked by uid 0); 24 Nov 2018 05:08:02 -0500'},
#   {'name': 'Message-ID', 'value': '<13.EB.28345.F5329FB5@momentum1-mta4>'},
#   {'name': 'X-AWMessage', 'value': 'f3a5b1af-f9c5-4d41-a287-46f6739970ba'},
#   {'name': 'Feedback-ID', 'value': 'A225535:L5038766:M31159144:AWeber'},
#   {'name': 'X-Subscribe-Method', 'value': 'webform'},
#   {'name': 'To', 'value': 'RICARDO PORTELA DA SILVA <ricaportela@gmail.com>'},
#   {'name': 'List-Unsubscribe',
#    'value': '<mailto:awlist5038766@aweber.com?subject=unsubscribe;rAzMHOxsbLTszBwsTGxMHLRmtMyMjKycjCws>, <http://www.aweber.com/z/r/?rAzMHOxsbLTszBwsTGxMHLRmtMyMjKycjCws>'},
#   {'name': 'X-Subscription',
#    'value': 'Subscribed on 07/19/2018, via web form, by 189.32.193.199, from https://forms.aweber.com/form/96/2072682896.htm'},
#   {'name': 'Subject',
#    'value': 'For Ricardo - Day 127 of 254 Days of Unstoppable Confidence!'},
#   {'name': 'X-Mailer', 'value': 'AWeber Spooler 2.6.13'},
#   {'name': 'Reply-To', 'value': 'Evan Carmichael <evan@evancarmichael.com>'},
#   {'name': 'From',
#    'value': 'Evan Carmichael <evan=evancarmichael.com@send.aweber.com>'},
#   {'name': 'Sender',
#    'value': 'Evan Carmichael <evan=evancarmichael.com@send.aweber.com>'}],
#  'body': {'size': 0},
#  'parts': [{'partId': '0',
#    'mimeType': 'text/plain',
#    'filename': '',
#    'headers': [{'name': 'Content-Transfer-Encoding',
#      'value': 'quoted-printable'},
#     {'name': 'MIME-Version', 'value': '1.0'},
#     {'name': 'Content-Type', 'value': 'text/plain; charset="utf-8"'}],
#    'body': {'size': 1020,
#     'data': '_-IFBQUy4gSWYgeW91J3JlIG1pc3NpbmcgZGF5cywgdGhleSB3ZXJlIHNlbnQuIENoZWNrIHlvdXIgc3BhbSBmb2xkZXIgYW5kIHdoaXRlIGxpc3QgdGhpcyBlbWFpbCA6KQ0KDQogICAgICBJbWFnZQ0KDQpodHRwOi8vY2xpY2tzLmF3ZWJlci5jb20veS9jdC8_...'}},
#   {'partId': '1',
#    'mimeType': 'text/html',
#    'filename': '',
#    'headers': [{'name': 'Content-Transfer-Encoding',
#      'value': 'quoted-printable'},
#     {'name': 'MIME-Version', 'value': '1.0'},
#     {'name': 'Content-Type', 'value': 'text/html; charset="utf-8"'}],
#    'body': {'size': 6906,
#     'data': 'PCFET0NUWVBFIGh0bWw-DQo8aHRtbCB4bWxuczp2PSJ1cm46c2NoZW1hcy1taWNyb3NvZnQtY29tOnZtbCI-...-DQoNCjxjZW50ZXI--DQogICAgICA8IS0tW2lmICFtc29dPjwhLS0--PCFbZW5kaWZdLS0-DQogICAgICAgIDx0Ym9keT48dHI-...-PHRyIGF3LWNvbnRlbnRzPSIxIj48dGQgYXctYXR0cmlidXRlcz0id2lkdGgsdmFsaWduIiBjbGFzcz0iY29udGFpbmVyIiBzdHlsZT0icGFkZGluZzogMHB4OyB3aWR0aDogMzMlOyIgYXctY29udGVudHM9IjEiIHdpZHRoPSIzMyUiIHZhbGlnbj0idG9wIj48ZGl2IGNsYXNzPSJkZWZpbml0aW9uLXBhcmVudCI-PGRpdiBjbGFzcz0icGFyYWdyYXBoIiBzdHlsZT0iZm9udC1zaXplOiAxMnB4OyI-PGRpdiBhdy12YXJpYWJsZT0icHJveGllZFZhbHVlIj48ZGl2PjxzcGFuIHN0eWxlPSJmb250LXNpemU6MTRweCI-SGkNClJpY2FyZG8uJm5ic3A7PC9zcGFuPjwvZGl2PjxkaXY-PGJyPjwvZGl2PjxkaXY-PGRpdj5IZXJlIGlzIERheSAxMjcmbmJzcDtvdXQgb2YgMjU0IHdpdGggRXZhbiBDYXJtaWNoYWVsLiBJdCdzIDA6NTYmbmJzcDtsb25nLjwvZGl2PjxkaXY-PGJyPjwvZGl2PjxkaXY-VHJ5IHRvIHdhdGNoIHdpdGhvdXQgZGlzdHJhY3Rpb25zIHRvIGdldCB0aGUgbWF4aW11bSBiZW5lZml0LiBFdmVyeSBkYXkgd2lsbCBzbG93bHkgc2hpZnQgeW91ciBjb25maWRlbmNlIGZvcndhcmQgYnV0IG9ubHkgaWYgeW91J3JlIHBheWluZyBhdHRlbnRpb24uPC9kaXY-PGRpdj48YnI-PC9kaXY-PGRpdj5FbmpveSE8YnI-PGJyPjxzcGFuIHN0eWxlPSJmb250LXNpemU6MTZweCI-PHN0cm9uZz4tLSZndDsmbmJzcDs8YQ0KZGF0YS1ja2Utc2F2ZWQtaHJlZj0iaHR0cDovL2NsaWNrcy5hd2ViZXIuY29tL3kvY3QvP2w9ODY1UEsmbT0zXzY1QVpvaDc2XzRlbkwmYj1CRFVHYTZIQUhrVEVEUlVSTTVEVGpnIiBocmVmPSJodHRwOi8vY2xpY2tzLmF3ZWJlci5jb20veS9jdC8_bD04NjVQSyZtPTNfNjVBWm9oNzZfNGVuTCZiPUJEVUdhNkhBSGtURURSVVJNNURUamciIGNsYXNzPSJ2YWxpZGF0aW5nIj5odHRwczovL3d3dy55b3V0dWJlLmNvbS93YXRjaD92PXNJUjdiQmdUeVBNJmFtcDtsaXN0PVVVS21rcG9FcWcxc09NR0VpSXlzUDhUdzwvYT4mbmJzcDsmbmJzcDs8L3N0cm9uZz48L3NwYW4-PGJyPuKAi-KAi-KAi-KAi-KAi-KAi-KAizxicj5NdWNoIGxvdmUsPGJyPjxicj5FdmFuLjxicj4jQmVsaWV2ZTxicj48YnI-UFMuIEknbSBkb2luZyBhIDkwIGRheSwgMjMgY2l0eSB0b3VyLiBBbSBJIGNvbWluZyB0byB5b3VyIGNpdHk_IGh0dHBzOi8vd3d3LmV2YW5jYXJtaWNoYWVsLmNvbS90b3VyLzxicj4mZ3Q7Jm5ic3A7UFBTLiBJZiB5b3UncmUgbWlzc2luZyBkYXlzLCB0aGV5IHdlcmUgc2VudC4gQ2hlY2sgeW91ciBzcGFtIGZvbGRlciBhbmQgd2hpdGUgbGlzdCB0aGlzIGVtYWlsDQo6KTwvZGl2PjxkaXY-PHA-PGJyPjwvcD48L2Rpdj48L2Rpdj48L2Rpdj48L2Rpdj48L2Rpdj48ZGl2IGNsYXNzPSJkZWZpbml0aW9uLXBhcmVudCI-PHNwYW4-PHRhYmxlIGFsaWduPSJjZW50ZXIiIHdpZHRoPSIxMDAlIiBjbGFzcz0iZmxvYXRlZC1ub25lIiBzdHlsZT0iZmxvYXQ6IG5vbmU7IHRleHQtYWxpZ246IGNlbnRlcjsgYm9yZGVyLXdpZHRoOiBtZWRpdW07IGJvcmRlci1zdHlsZTogbm9uZTsiIHJvbGU9InByZXNlbnRhdGlvbiI-DQogIDx0Ym9keT48dHI-DQogICAgPHRkIHN0eWxlPSJwYWRkaW5nOiAwcHggMHB4IDEycHggMHB4OyI-...-DQogIDwvdHI-DQo8L3Rib2R5PjwvdGFibGU-..._...-DQogIDwvdHI-DQo8L3Rib2R5PjwvdGFibGU-PC9zcGFuPjwvZGl2PjwvdGQ-PC90cj48L3Rib2R5PjwvdGFibGU-PC9kaXY-DQo8L2Rpdj4NCiAgICAgICAgICAgIDwvZGl2Pg0KICAgICAgICAgIDwvdGQ-DQogICAgICAgIDwvdHI-DQogICAgICA8L3Rib2R5PjwvdGFibGU-DQogICAgPC90ZD4NCiAgPC90cj4NCjwvdGJvZHk-PC90YWJsZT4NCjxkaXYgc3R5bGU9ImNsZWFyOiBib3RoIWltcG9ydGFudDsiPjwvZGl2PjwvZGl2Pg0KPC9jZW50ZXI--DQoNClRvcm9udG8gRGFuY2UgU2Fsc2EsIGF0dGVudGlvbjogRXZhbiBDYXJtaWNoYWVsPGJyIC8-DQo1MDk1IFlvbmdlIFN0cmVldDxiciAvPg0KVG9yb250byBPbnRhcmlvIE0yTiA2WjQgPGJyIC8-DQpDQU5BREE8YnIgLz4NCjxhIGhyZWY9Imh0dHA6Ly93d3cuYXdlYmVyLmNvbS96L3IvP3JBek1IT3hzYkxUc3pCd3NUR3hNSExSbXRNeU1qS3ljakN3cyIgc3R5bGU9ImNvbG9yOiAjMDBmICFpbXBvcnRhbnQ7Ij5VbnN1YnNjcmliZTwvYT4gfCA ...

# %%
for msg in ListMessagesMatchingQuery():
    for k, v in msg.items():
        print(k, v)
        # message = service.users().messages().get(userId=user_id, id=m_id).execute() # fetch the message using API
# Out:
# id 1674530c2425b086
# threadId 1674530c2425b086
# id 1674007bfa9604a4
# threadId 1674007bfa9604a4
# id 1673ae75b0038dc3
# threadId 1673ae75b0038dc3
# id 16735bafa75d0736
# threadId 16735bafa75d0736
# id 16730961367c3b48
# threadId 16730961367c3b48
# id 1672b824e7870e29
# threadId 1672b824e7870e29
# id 167264e55fd5db48
# threadId 167264e55fd5db48
# id 16721278c8dc914e
# threadId 16721278c8dc914e
# id 1671c0b154175662
# threadId 1671c0b154175662
# id 16716daa8329fb50
# threadId 16716daa8329fb50
# id 16711b08083b144a
# threadId 16711b08083b144a
# id 1670c931f314aa47
# threadId 1670c931f314aa47
# id 1670772fe2c495aa
# threadId 1670772fe2c495aa
# id 16702445cdba40cf
# threadId 16702445cdba40cf
# id 166fd163c5f7e999
# threadId 166fd163c5f7e999
# id 166f7f613fc87d09
# threadId 166f7f613fc87d09
# id 166f2d1d0967bdba
# threadId 166f2d1d0967bdba
# id 166eda3546ed901d
# threadId 166eda3546ed901d
# id 166e87d8607fd6a5
# threadId 166e87d8607fd6a5
# id 166e353313682ee4
# threadId 166e353313682ee4
# id 166de2b65333c704
# threadId 166de2b65333c704
# id 166d8cdfe38f89ca
# threadId 166d8cdfe38f89ca
# id 166d3bf5ee4a5afd
# threadId 166d3bf5ee4a5afd
# id 166ce83b746d4d6c
# threadId 166ce83b746d4d6c
# id 166c95dcfaca76ec
# threadId 166c95dcfaca76ec
# id 166c43b4014ab0be
# threadId 166c43b4014ab0be
# id 166bf1e058f14041
# threadId 166bf1e058f14041
# id 166b9f2e6e9dd03e
# threadId 166b9f2e6e9dd03e
# id 166b4cb3128118ee
# threadId 166b4cb3128118ee
# id 166afaca0b890b1d
# threadId 166afaca0b890b1d
# id 166aa76080e9e990
# threadId 166aa76080e9e990
# id 166a5592768950a0
# threadId 166a5592768950a0
# id 166a03582b160320
# threadId 166a03582b160320
# id 1669b0421bf75c79
# threadId 1669b0421bf75c79
# id 16695e4f52b3fa4d
# threadId 16695e4f52b3fa4d
# id 16690ba5f3cace19
# threadId 16690ba5f3cace19
# id 1668b8e3931cee19
# threadId 1668b8e3931cee19
# id 166814eb1c37d91d
# threadId 166814eb1c37d91d
# id 1667c26743e9f692
# threadId 1667c26743e9f692
# id 16676f544da1f8ce
# threadId 16676f544da1f8ce
# id 16671d42414d2c06
# threadId 16671d42414d2c06
# id 1666cb10522a7e5c
# threadId 1666cb10522a7e5c
# id 1666790563ba50c3
# threadId 1666790563ba50c3
# id 16662670ead0a16a
# threadId 16662670ead0a16a
# id 1665d3b30f4547b1
# threadId 1665d3b30f4547b1
# id 16658122ef83cb1d
# threadId 16658122ef83cb1d
# id 16652e96b4f32776
# threadId 16652e96b4f32776
# id 166437d97e2338cb
# threadId 166437d97e2338cb
# id 1663e5703206c5d0
# threadId 1663e5703206c5d0
# id 166392bbdd9500db
# threadId 166392bbdd9500db
# id 1663412f0af73551
# threadId 1663412f0af73551
# id 1662ef05734bddc3
# threadId 1662ef05734bddc3
# id 1662497bdde58786
# threadId 1662497bdde58786
# id 1661f75726fb91a9
# threadId 1661f75726fb91a9
# id 1661a45994592a04
# threadId 1661a45994592a04
# id 1661526031445b40
# threadId 1661526031445b40
# id 1661008ce2c893ed
# threadId 1661008ce2c893ed
# id 16605adc1e4e68d0
# threadId 16605adc1e4e68d0
# id 1660089857ea1819
# threadId 1660089857ea1819
# id 165fb654955cc4bd
# threadId 165fb654955cc4bd
# id 165f11aa271d144a
# threadId 165f11aa271d144a
# id 165ebe9538859c1d
# threadId 165ebe9538859c1d
# id 165e6d484ae5691f
# threadId 165e6d484ae5691f
# id 165e1a9385500481
# threadId 165e1a9385500481
# id 165dc82c29cfe619
# threadId 165dc82c29cfe619
# id 165d76216891c749
# threadId 165d76216891c749
# id 165d2317605c1be3
# threadId 165d2317605c1be3
# id 165cd0fb4120bc65
# threadId 165cd0fb4120bc65
# id 165c7e1f812860ae
# threadId 165c7e1f812860ae
# id 165c2b73d72f8226
# threadId 165c2b73d72f8226
# id 165bd913b9cfed48
# threadId 165bd913b9cfed48
# id 165b87327fb82e96
# threadId 165b87327fb82e96
# id 165b358266ba6ff5
# threadId 165b358266ba6ff5
# id 165ae269f8b6b692
# threadId 165ae269f8b6b692
# id 165a901a12383e0d
# threadId 165a901a12383e0d
# id 165a3dc1e6684439
# threadId 165a3dc1e6684439
# id 1659ebbf2b71c5a5
# threadId 1659ebbf2b71c5a5
# id 165998546847d300
# threadId 165998546847d300
# id 1659465c9fd32eb6
# threadId 1659465c9fd32eb6
# id 1658f497765f968c
# threadId 1658f497765f968c
# id 1658a191611e37bd
# threadId 1658a191611e37bd
# id 16584eaea0a72608
# threadId 16584eaea0a72608
# id 1657fd974da953dd
# threadId 1657fd974da953dd
# id 1657aaa3af8d5961
# threadId 1657aaa3af8d5961
# id 165758a693b9c6ce
# threadId 165758a693b9c6ce
# id 1657055f28a70898
# threadId 1657055f28a70898
# id 1656b392ffc21201
# threadId 1656b392ffc21201
# id 16566102b1e01d7c
# threadId 16566102b1e01d7c
# id 16560ec788251a13
# threadId 16560ec788251a13
# id 1655bc2a940692c7
# threadId 1655bc2a940692c7
# id 16556929361d8015
# threadId 16556929361d8015
# id 16551755d01ad727
# threadId 16551755d01ad727
# id 1654c4f2616bd937
# threadId 1654c4f2616bd937
# id 16541fad17f1ce12
# threadId 16541fad17f1ce12
# id 1653cd9ad4db01ec
# threadId 1653cd9ad4db01ec
# id 16537bc6f7f37142
# threadId 16537bc6f7f37142
# id 165328ef4b161697
# threadId 165328ef4b161697
# id 1652d671cac7abb9
# threadId 1652d671cac7abb9
# id 165283749580d679
# threadId 165283749580d679
# id 165231f170821376
# threadId 165231f170821376
# id 1651df5f0e9f7dd3
# threadId 1651df5f0e9f7dd3
# id 16518d0a174fdb41
# threadId 16518d0a174fdb41
# id 16513a27cb684554
# threadId 16513a27cb684554
# id 1650e85825058fc9
# threadId 1650e85825058fc9
# id 1650957ca13bb1d6
# threadId 1650957ca13bb1d6
# id 1650433971d0ba2b
# threadId 1650433971d0ba2b
# id 164ff0ff261b7185
# threadId 164ff0ff261b7185
# id 164f9ebb8a7c8458
# threadId 164f9ebb8a7c8458
# id 164f4c2b4dc8edf1
# threadId 164f4c2b4dc8edf1
# id 164ef9d7ddd8f896
# threadId 164ef9d7ddd8f896
# id 164ea8c5b7a81e7a
# threadId 164ea8c5b7a81e7a
# id 164e552a12be1b5f
# threadId 164e552a12be1b5f
# id 164e01f4df2d9dae
# threadId 164e01f4df2d9dae
# id 164db0892dab39d5
# threadId 164db0892dab39d5
# id 164d5dc27b415f18
# threadId 164d5dc27b415f18
# id 164d0b227cf65d6b
# threadId 164d0b227cf65d6b
# id 164c662a50a95b20
# threadId 164c662a50a95b20
# id 164c142087af0ea8
# threadId 164c142087af0ea8
# id 164bc1c25e7c60be
# threadId 164bc1c25e7c60be
# id 164b50dcc44620e9
# threadId 164b50dcc44620e9
